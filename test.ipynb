# %%
import pandas as pd

# %%
df = pd.read_parquet("o.parquet")

len(df), df["id"].nunique()
# Out:
# (109096, 109096)

# %%
df.sample(1)
# Out:
#              id             title  \
# 23854  68011907  Oil Springs Fire
#
#                                                     text  \
# 23854  The Oil Springs Fire was a wildfire that start...
#
#                                               categories
# 23854  [2021 Colorado wildfires, June 2021 events in ...
